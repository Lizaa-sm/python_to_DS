# %% [markdown]
# ## **Introduction Seaborn - Python for Data Visualization**
#
# Seaborn is a Python data visualization library built on top of matplotlib. It was designed to make it easier to create beautiful and informative statistical graphics with less code. Seaborn comes with attractive default styles and works seamlessly with pandas DataFrames. It also provides high-level functions for common statistical plots, such as boxplots, heatmaps, probability distributions, regression plots, and more.
#
# You can find open source examples through the following link:(Tutorial or Gallery) https://seaborn.pydata.org/examples/wide_data_lineplot.html

# %% [markdown]
# ``Seaborn`` is a Python visualization library that comes with several built-in datasets for learning and testing. Among the most well-known are ``iris`` and ``tips``, which are quite different. The ``iris`` dataset contains measurements of sepals and petals from three flower species, and it is often used in machine learning and classification tasks. The ``tips`` dataset, on the other hand, provides information about restaurant ``bills`` and ``tips``, including variables such as total bill, tip amount, customer gender, smoker status, day of the week, and party size, making it very useful for statistical analysis.
#
# In addition to these, Seaborn includes many other datasets such as ``flights`` (air passenger data over time), ``penguins`` (penguin measurements, often used as a modern alternative to iris), ``diamonds`` (price, color, and cut of diamonds), ``titanic`` (survival on the Titanic), ``exercise`` (physical activity data), ``planets`` (planet discoveries), ``mpg`` (car fuel consumption) and ``anscombe`` (The famous “Anscombe’s quartet” used to show the importance of visualizing data.). These datasets are helpful for practicing visualizations and learning how to apply statistical techniques to different types of information.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# For you to see graphs
# %matplotlib inline

# %%
# To load a dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(1,1), dpi=65)

# distribution plot (histogram + KDE density curve) of the total_bill column of the DataFrame tp.
sns.displot(tips['total_bill'], kde=True, bins=20)

# %% [markdown]
# **sns.jointplot →** creates a plot showing the relationship between two variables along with marginal distributions on the axes.
# **x='total_bill' →** variable on the X-axis (total bill).
# **y='tip' →** variable on the Y-axis (tip).
# **data=tips →** uses the tips dataset.
# **kind='hex' →** plots a hexbin plot, where the plane is divided into hexagons, and the color intensity represents the number of data points in that area.
# * This is useful when you have a lot of overlapping data points, because the hexagons make density patterns clearer.

# %%
# Read above
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %% [markdown]
# * The kind parameter controls how the main relationship between variables is displayed:
# **kind='scatter' →** creates a standard scatter plot (individual dots).
# **kind='hex' →** creates a hexbin plot (hexagons showing data density).
# **kind='kde' →** shows kernel density contours, highlighting regions with higher concentration.
# **kind='reg' →** scatter plot with a regression line fitted to the data.
# **kind='hist' →** uses a 2D histogram to represent density instead of hexagons.

# %%
# Read above
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %% [markdown]
# * **sns.pairplot →** creates a grid of plots (scatterplot matrix).
# It plots all pairwise relationships between numerical variables in the tips dataset.
# For each pair of variables **→** it shows a scatter plot.
# On the main diagonal **→** it shows the distribution (histogram or kde) of each variable individually.
# *This is a powerful tool for exploratory data analysis (EDA), because it quickly reveals correlations and patterns among variables.

# %%
# colors and lines 
# you can also do: palette='coolwarm' for change color
sns.pairplot(tips, hue='sex', kind='reg')

# %% [markdown]
# * **sns.rugplot →** creates a rug plot. It draws small vertical lines (ticks) along the X-axis, each representing one data point. In this case, every total bill value is marked on the axis. This helps to visualize the distribution of the data in a very compact way. Rug plots are often combined with kde plots or histograms to provide extra detail.

# %%
sns.kdeplot(tips['total_bill'], shade=True)
sns.rugplot(tips['total_bill'])
# Out:
# C:\Users\monin\AppData\Local\Temp\ipykernel_6572\1685850492.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>
