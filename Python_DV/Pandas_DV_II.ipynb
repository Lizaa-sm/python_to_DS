# %% [markdown]
# ## **Pandas with Data Visualization**
#
# * **Now, let's look at another library.**
#
# **Plotly =** library for creating interactive visualizations.
# **Cufflinks =** extension that integrates Pandas + Plotly, making it easier to create interactive plots directly from DataFrames.

# %%
import numpy as np
import pandas as pd
import plotly as __version__
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys
# !{sys.executable} -m pip install cufflinks

# %%
import cufflinks as cf
# cf.go_offline()

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %% [markdown]
# * ``**init_notebook_mode(connected=True):**`` loads Plotly’s JavaScript resources from the internet.
# * ``**init_notebook_mode(connected=False):**`` loads the resources offline, without requiring an internet connection (uses local files). After running this, you can display Plotly charts directly inside Jupyter Notebook without needing to call ``fig.show()``.

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# * **from** ``plotly.offline`` **import** ``init_notebook_mode``: Comes from **Plotly** itself and enables Plotly charts to be displayed in Jupyter (either online or offline).
# * ``cf.go_offline()`` : Comes from **Cufflinks** and specifically tells Cufflinks to use Plotly in offline mode, so charts can be rendered directly inside Jupyter Notebook without an internet connection.

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Presenting Data
df = pd.DataFrame(np.random.randn(1000,4), columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0 -0.945744  1.901285 -0.143442  0.137101
# 1  0.950056 -0.133689  0.129659  0.819851
# 2 -0.123704 -1.855012 -0.024138  0.389026
# 3 -1.187520 -0.168274 -0.516674  0.284988
# 4  0.757152 -0.499919 -1.040280  2.071395

# %%
# Creating another Data Frame
df_II = pd.DataFrame({'Columns':['A', 'B', 'C', 'D'], 'Values':[10, 20, 30, 40]})
df_II
# Out:
#   Columns  Values
# 0       A      10
# 1       B      20
# 2       C      30
# 3       D      40

# %%
df.iplot()
# You can do
# df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>                            <div id="8cb0306e-5db1-4b97-bd6d-fd0ef3e82479" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# You can do:
df_II.iplot(kind='bar', x='Columns', y='Values', colors='red')
df.sum().iplot(kind='bar', colors='green')
df.iplot(kind='box')
# Out:
# <div>                            <div id="3b271c48-c4af-4642-bfba-2603a3ec3c52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_III = pd.DataFrame({'x':[1, 2, 3, 4, 5],'y':[10, 20, 30, 20, 10], 'z':[5,4,3,2,1] })

df_III.iplot(kind='surface')
# Out:
# <div>                            <div id="dafc65f0-2e4b-4916-912b-2fa44a912f8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="bdc09a5f-eb0f-4aa1-8d19-f19c23c9be71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
